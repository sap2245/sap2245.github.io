# %%
import pandas as pd

# %%
df = pd.read_csv('WDI_data.csv')

# %%
df1 = pd.df('Country Name')
df2 = pd.df('World')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1 = pd.df('Country Name')
#       2 df2 = pd.df('World')
#
# AttributeError: module 'pandas' has no attribute 'df'
